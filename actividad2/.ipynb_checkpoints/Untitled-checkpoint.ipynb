# 31   THERE has been a change of government. It beg...
# 32   My Fellow Citizens:  THE four years which hav...
# 33   My Countrymen:  WHEN one surveys the world ab...
# 34   My Countrymen:  NO one can contemplate curren...
# 35   My Countrymen:  THIS occasion is not alone th...
# 36   I AM certain that my fellow Americans expect ...
# 37   WHEN four years ago we met to inaugurate a Pr...
# 38   ON each national day of inauguration since   ...
# 39   MR. Chief Justice, Mr. Vice President, my fri...
# 40   Mr. Vice President, Mr. Chief Justice, and fe...
# 41   MY friends, before I begin the expression of ...
# 42   THE PRICE OF PEACE Mr. Chairman, Mr. Vice Pre...
# 43   Vice President Johnson, Mr. Speaker, Mr. Chie...
# 44   My fellow countrymen, on this occasion, the o...
# 45   Senator Dirksen, Mr. Chief Justice, Mr. Vice ...
# 46   Mr. Vice President, Mr. Speaker, Mr. Chief Ju...
# 47   FOR myself and for our Nation, I want to than...
# 48   Senator Hatfield, Mr. Chief Justice, Mr. Pres...
# 49   Senator Mathias, Chief Justice Burger, Vice P...
# 50   Mr. Chief Justice, Mr. President, Vice Presid...
# 51   My fellow citizens:Today we celebrate the mys...
# 52   My fellow citizens:At this last presidential ...
# 53   President Clinton, distinguished guests and m...
# 54   Vice President Cheney, Mr. Chief Justice, Pre...
# 55   My fellow citizens:    I stand here today hum...
# 56   Vice President Biden, Mr. Chief Justice, Memb...
# 57  Chief Justice Roberts, President Carter, Presi...

# %% [markdown]
# Hola...

# %%
#selección de los mensajes
docs = df_speeches["text"].as_matrix()
len(docs)
# Out:
# 58

# %%
import nltk # natural language tool kit
nltk.download('stopwords') # descarga diccionario de stopwords
nltk.download('punkt') # descarga ...
# load nltk's SnowballStemmer as variabled 'stemmer'
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics import adjusted_rand_score

stemmer = SnowballStemmer("english")

# load nltk's English stopwords as variable called 'stopwords'
stopwords = nltk.corpus.stopwords.words('english')
stopwords.append('government')
stopwords.append('american')
stopwords.append('united')
stopwords.append('states')

# here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens
# Out:
# [nltk_data] Downloading package stopwords to /home/alan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/alan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# K-means

import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer 
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

#vectorizer = TfidfVectorizer(stop_words='english',tokenizer=tokenize_and_stem, ngram_range=(1,2))
vectorizer = TfidfVectorizer(stop_words='english',tokenizer=tokenize_only, ngram_range=(1,2))
X = vectorizer.fit_transform(docs) # aplicar sobre nuestro documento
num_k = range(1, 20)
inertias = []

for k in num_k: # tomamos 20 valores de k para ver cuál sería el k óptimo
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters=k, n_init=10)

    # Fit model to samples
    model.fit(X)

    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)



# Plot ks vs inertias
plt.plot(num_k, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(num_k)
plt.show()

# %%
true_k = 2 # El valor justo antes de que haya una disminución en la pendiente (entre los valores del gráfico anterior)

# %%
#Aplicando Modelos Probabilistas de Tópicos y LDA
from sklearn.decomposition import LatentDirichletAllocation

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

tf_vectorizer = CountVectorizer(max_df=0.15, min_df=5,
                                stop_words=stopwords,tokenizer=tokenize_only, ngram_range=(2,2))
# max_df=0.90 si aparecen en el 90% de los documentos las saca
# min_df= si la frecuencia de aparición es 2 (muy baja) las saca
tf = tf_vectorizer.fit_transform(docs)
diccionario= tf_vectorizer.get_feature_names()


#Estimación de LDA con Bayes Variacional
#for i in range(10):
lda = LatentDirichletAllocation(n_components=14, max_iter=10,
                                learning_method='online',
                                learning_offset=50., # Revisar qué es cada uno de estos parámetros...
                                random_state=0)

lda.fit(tf)
#Cálculo de índice de ajuste de los datos
print(lda.perplexity(tf))
print("\nTopics in LDA model:")
print_top_words(lda, diccionario, 10)
# Out:
# 2121.101049053491
#
# Topics in LDA model:
# Topic #0: political parties old world within limits state governments public opinion rests upon imposed upon great national time history economy public
# Topic #1: old world pursuit happiness america america made us must act oath taken rest upon two centuries thank god time history
# Topic #2: america 's america must new world pursuit happiness must go thank god people let constitution laws congress may shall secure
# Topic #3: public private service country depend upon common defense far may regard rights agriculture commerce public opinion eight years great national
# Topic #4: america 's people 's every nation free institutions citizens world generation americans human life time come new era solemn oath
# Topic #5: body people peace shall constitution laws social order public officers shall take domestic institutions every man section country love liberty
# Topic #6: new era public money us remember know america powerful nation one us time peace time come bless america sense responsibility
# Topic #7: common good lasting peace human dignity chief magistrate every nation time history people whose every part blessings liberty every man
# Topic #8: within limits north south civil war upon people indian tribes highest degree earnest desire imposed upon rest upon years since
# Topic #9: may necessary best ability best interests faithfully executed nations earth common country respect rights take oath executive departments great interests
# Topic #10: religious liberty civil religious called upon prescribed constitution public money whole country chief magistrate great people solemn oath public service
# Topic #11: go forward men 's justice mr. us free natural resources every man must act thank god among us century ago
# Topic #12: best interests public expenditures foreign policy nations earth civil service great people public servants made great people 's shall endeavor
# Topic #13: shall endeavor thank god would seem bless america public officers foreign affairs great national imposed upon enter upon human life

# %%
#Generando algunos gráficos de los resultados
from matplotlib.pylab import hist, show
import seaborn as sns

y=lda.fit_transform(tf)

#distribución de tópicos en todos los documentos
dist = sum(y)/len(docs)
w=np.arange(0,true_k)
plt.bar(w,height=dist,alpha=0.5,tick_label=w)
show()
#distribución de tópicos en el documento 100
plt.bar(w,height=y[100],alpha=0.5,tick_label=w)
show()


#frecuencia de palabras por tópico
n_top_words=15
numo =np.arange(0,n_top_words)
for idx,topic in enumerate(lda.components_):
    d =[]
    s = []
    for i in topic.argsort()[:-n_top_words - 1:-1]:
          s.append(diccionario[i])
          d.append(topic[i])
    
    plt.barh(numo,width=d,alpha=0.5,tick_label=s)
    show()
